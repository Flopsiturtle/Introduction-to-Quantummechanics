# %%
import numpy as np
# %display latex
from scipy import constants

pi = constants.pi
hbar = 1
x, t = var('x', 't')
Psi = var('Psi')
assume(x, 'real')
assume(t, 'real')

# %% [markdown]
# $V(x) = \frac12 m\omega^2x^2$
#
# $\Psi_n(x,t) = \psi_n(x)\phi_n(t)$
#
# $\xi = \sqrt{\frac{m\omega}{\hbar}}x$
#
# $\psi_n(\xi) = (\frac{m\omega}{2\hbar})^{\frac{1}{4}}\frac{1}{\sqrt{2^nn!}}H_n(\xi)e^{-\frac{\xi^2}{2}}$
#
# $H_n(\xi)$ are the Hermite Polynomials
#
# $\phi_n(x) = e^{-i\frac{E_n}{\hbar}t}$
#
# $E_n = (n+\frac12)\hbar\omega$

# %%
def H(n,xi):
    H = [1, 2*xi, 4*xi^2-2, 8*xi^3-12*xi, 16*xi^4-48*xi^2+12, 32*xi^5-160*xi^3+120*xi]
    return H[n]

# %%
gamma(3)
# Out:
# 2

# %%
m = 1
w = 1
xi = sqrt((m*w)/(hbar))*x

n_max = 3
E_max = (n_max+0.5)*hbar*w
colors = ['black', 'red', 'blue', 'green']
x_range = (-sqrt(2*1.3*E_max/(m*w^2)),1.3*sqrt(2*1.3*E_max/(m*w^2)))

S = plot(0.5*m*w^2*x^2, x_range, color = colors[0], legend_label='V')

P = animate([plot(0, x_range, legend_label = 'E_n', color = colors[1]) + plot(0, x_range, color = colors[2], legend_label = 'Real') + plot(0, x_range, color = colors[3], legend_label = 'Imaginary') for t_val in sxrange(0,(hbar)/(0.5*hbar*w)*2*pi, .01)])
for i in range(len(P)):
    P[i].set_legend_options(loc=1)

P += animate([plot(0.5*m*w^2*x^2, color = colors[0], legend_label = 'V') + plot(0, x_range, legend_label = 't = ' + str(round(t_val,2)), color = 'black',axes_labels=['x','E']) for t_val in sxrange(0,(hbar)/(0.5*hbar*w)*2*pi, .01)] )


for n in range(n_max+1):
    E = (n+0.5)*hbar*w
    psi = (m*w/(2*hbar))^(1/4)*1/(sqrt(2^n*gamma(n+1)))*H(n,xi)*e^(-0.5*xi^2)
    phi = e^(-I*E*t/hbar)
    
    eqAbs = Psi*Psi.conjugate() == psi*phi*psi*phi.conjugate()
    eqRe = Psi == psi*phi.real()
    eqIm = Psi == psi*phi.imag()
    
    S += plot(E, x_range, color = colors[1]) + plot(eqAbs.rhs()+E, x_range, color = 'black')
    P += animate([plot(eqRe.rhs()(t=t_val)+E, x_range, color = colors[2]) + plot(eqIm.rhs()(t=t_val)+E, x_range, color = colors[3]) + plot(E, x_range, color = colors[1]) for t_val in sxrange(0,(hbar)/(0.5*hbar*w)*2*pi, .01)] )

S
P.show(delay=2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-88a3dd814197> in <module>
#      30
#      31 S
# ---> 32 P.show(delay=Integer(2))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/animate.py in show(self, delay, iterations, **kwds)
#     777         from sage.repl.rich_output import get_display_manager
#     778         dm = get_display_manager()
# --> 779         dm.display_immediately(self, **kwds)
#     780
#     781     def _have_ffmpeg(self):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/repl/rich_output/display_manager.py in display_immediately(self, obj, **rich_repr_kwds)
#     838             1/2
#     839         """
# --> 840         plain_text, rich_output = self._rich_output_formatter(obj, rich_repr_kwds)
#     841         self._backend.display_immediately(plain_text, rich_output)
#     842
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/repl/rich_output/display_manager.py in _rich_output_formatter(self, obj, rich_repr_kwds)
#     627         has_rich_repr = isinstance(obj, SageObject) and hasattr(obj, '_rich_repr_')
#     628         if has_rich_repr:
# --> 629             rich_output = self._call_rich_repr(obj, rich_repr_kwds)
#     630         if isinstance(rich_output, OutputPlainText):
#     631             plain_text = rich_output
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/repl/rich_output/display_manager.py in _call_rich_repr(self, obj, rich_repr_kwds)
#     585         if rich_repr_kwds:
#     586             # do not ignore errors from invalid options
# --> 587             return obj._rich_repr_(self, **rich_repr_kwds)
#     588         try:
#     589             return obj._rich_repr_(self)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/animate.py in _rich_repr_(self, display_manager, **kwds)
#     675         if suffix is not None:
#     676             return display_manager.graphics_from_save(
# --> 677                 self.save, kwds, suffix, outputType)
#     678
#     679         # Now we save for OutputVideoBase
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/repl/rich_output/display_manager.py in graphics_from_save(self, save_function, save_kwds, file_extension, output_container, figsize, dpi)
#     715         if dpi is not None:
#     716             kwds['dpi'] = dpi
# --> 717         save_function(filename, **kwds)
#     718         from sage.repl.rich_output.buffer import OutputBuffer
#     719         buf = OutputBuffer.from_file(filename)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/animate.py in save(self, filename, show_path, use_ffmpeg, **kwds)
#    1080         if filename is None or suffix == '.gif':
#    1081             self.gif(savefile=filename, show_path=show_path,
# -> 1082                      use_ffmpeg=use_ffmpeg, **kwds)
#    1083         elif suffix == '.sobj':
#    1084             SageObject.save(self, filename)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/animate.py in gif(self, delay, savefile, iterations, show_path, use_ffmpeg)
#     604                 savefile += '.gif'
#     605             savefile = os.path.abspath(savefile)
# --> 606             d = self.png()
#     607             cmd = ( 'cd "%s"; sage-native-execute convert -dispose Background '
#     608                     '-delay %s -loop %s *.png "%s"' ) % ( d, int(delay),
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/animate.py in png(self, dir)
#     466                 self.make_image(frame, filename, **self._kwds)
#     467             else:
# --> 468                 save_image(filename, **self._kwds)
#     469             i += 1
#     470         self._num_frames = i
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/graphics.py in save_image(self, filename, *args, **kwds)
#    3199             sage: c.save_image(filename, xmin=-1, xmax=3, ymin=-1, ymax=3)
#    3200         """
# -> 3201         self.save(filename, *args, **kwds)
#    3202
#    3203
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     408             kwds[self.name + "options"] = suboptions
#     409
# --> 410             return func(*args, **kwds)
#     411
#     412         # Add the options specified by @options to the signature of the wrapped
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/graphics.py in save(self, filename, **kwds)
#    3361                 opts['bbox_extra_artists'] = self._bbox_extra_artists
#    3362
# -> 3363             figure.savefig(filename, **opts)
#    3364
#    3365             # Restore the rcParams to the original, possibly user-set values
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/legend.py in draw(self, renderer)
#     612
#     613         self.legendPatch.draw(renderer)
# --> 614         self._legend_box.draw(renderer)
#     615
#     616         renderer.close_group('legend')
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/offsetbox.py in draw(self, renderer)
#     360         for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     361             c.set_offset((px + ox, py + oy))
# --> 362             c.draw(renderer)
#     363
#     364         bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/offsetbox.py in draw(self, renderer)
#     360         for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     361             c.set_offset((px + ox, py + oy))
# --> 362             c.draw(renderer)
#     363
#     364         bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/offsetbox.py in draw(self, renderer)
#     360         for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     361             c.set_offset((px + ox, py + oy))
# --> 362             c.draw(renderer)
#     363
#     364         bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/offsetbox.py in draw(self, renderer)
#     360         for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     361             c.set_offset((px + ox, py + oy))
# --> 362             c.draw(renderer)
#     363
#     364         bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/offsetbox.py in draw(self, renderer)
#     911     def draw(self, renderer):
#     912         # docstring inherited
# --> 913         self._text.draw(renderer)
#     914         bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     915         self.stale = False
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     727                     textrenderer.draw_text(gc, x, y, clean_line,
#     728                                            textobj._fontproperties, angle,
# --> 729                                            ismath=ismath, mtext=mtext)
#     730
#     731         gc.restore()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     193
#     194         flags = get_hinting_flag()
# --> 195         font = self._get_agg_font(prop)
#     196
#     197         if font is None:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in _get_agg_font(self, prop)
#     271         """
#     272         fname = findfont(prop)
# --> 273         font = get_font(fname)
#     274
#     275         font.clear()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1412     # Resolving the path avoids embedding the font twice in pdf/ps output if a
#    1413     # single font is selected using two different relative paths.
# -> 1414     filename = os.path.realpath(filename)
#    1415     if hinting_factor is None:
#    1416         hinting_factor = rcParams['text.hinting_factor']
#
# /usr/lib/python3.7/posixpath.py in realpath(filename)
#     393 symbolic links encountered in the path."""
#     394     filename = os.fspath(filename)
# --> 395     path, ok = _joinrealpath(filename[:0], filename, {})
#     396     return abspath(path)
#     397
#
# /usr/lib/python3.7/posixpath.py in _joinrealpath(path, rest, seen)
#     427             continue
#     428         newpath = join(path, name)
# --> 429         if not islink(newpath):
#     430             path = newpath
#     431             continue
#
# /usr/lib/python3.7/posixpath.py in islink(path)
#     169     """Test whether a path is a symbolic link"""
#     170     try:
# --> 171         st = os.lstat(path)
#     172     except (OSError, AttributeError):
#     173         return False
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

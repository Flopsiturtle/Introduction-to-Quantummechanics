# %%
import numpy as np
# %display latex

Psi = var('Psi')
x = var('x')
A, a, b = var('A', 'a', 'b')

assume(A>0, a>0, b>0)

eq0 = Psi == piecewise([((-oo,0), 0), ((0,1),A*(x/a)), ([1, 2],A*(b-x)/(b-a)), ((2,+oo),0)], var=x)
show(eq0)
plot(eq0.lhs()(A=2, a=1, b=2),(-5,5))
# Out:
# piecewise(x|-->0 on (-oo, 0), x|-->A*x/a on (0, 1), x|-->-A*(b - x)/(a - b) on [1, 2], x|-->0 on (2, +oo); x) == Psi
# Graphics object consisting of 1 graphics primitive
